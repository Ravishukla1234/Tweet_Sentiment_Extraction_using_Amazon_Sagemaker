# %% [markdown]
# # Data Preparation and Training
#
# In this notebook, we are going to run `sentiment extraction(question answer)` training on Amazon Sagemaker powered by hugging face.

# %% [markdown]
# ---
#
# # Data Preparation

# %% [markdown]
# ## Load required libraries

# %%
import pandas as pd
import numpy as np
import os

import sagemaker
import boto3
import json

import sagemaker
from sagemaker import get_execution_role
from sagemaker.huggingface import HuggingFace

from sagemaker.s3 import S3Downloader
from sagemaker.s3 import S3Uploader

data_dir = "../inputs"

sagemaker_session = sagemaker.Session()
region = sagemaker_session.boto_region_name
role = get_execution_role()
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ---
#
# # Train Roberta model using Amazon Sagemaker

# %%
train_file_location = f"{data_dir}/train.csv"
bucket = sagemaker_session.default_bucket()
prefix = "sentiment_extraction/data"


inputs = S3Uploader.upload(train_file_location, "s3://{}/{}".format(bucket, prefix))

inputs = "s3://{}/{}".format(bucket, prefix)
print(inputs)
# Out:
# s3://sagemaker-ap-south-1-296512243111/sentiment_extraction/data

# %%
hyperparameters = {
    "model_name": "roberta-base",
    "batch_size": 16,
    "epochs": 5,
    "lr": 2e-5,
}

# %%
local_script_location = "../src"
hub = {"HF_TASK": "question-answering"}  ## NLP task you want to use for predictions
huggingface_estimator = HuggingFace(
    entry_point="train.py",
    source_dir=local_script_location,
    env=hub,
    instance_type="ml.g4dn.12xlarge",
    #         instance_type='ml.p2.xlarge',
    instance_count=1,
    role=role,
    transformers_version="4.6",
    pytorch_version="1.7",
    py_version="py36",
    hyperparameters=hyperparameters,
)
huggingface_estimator.fit(inputs)
# Out:
# 2023-01-09 13:24:47 Starting - Starting the training job...
# 2023-01-09 13:25:13 Starting - Preparing the instances for trainingProfilerReport-1673270687: InProgress
# .........
# 2023-01-09 13:26:32 Downloading - Downloading input data...
# 2023-01-09 13:27:16 Training - Downloading the training image...
# 2023-01-09 13:27:46 Training - Training image download completed. Training in progress......bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-09 13:28:32,372 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-09 13:28:32,419 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-09 13:28:32,421 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-09 13:28:32,687 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 16,
#         "epochs": 5,
#         "lr": 2e-05,
#         "model_name": "roberta-base"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2023-01-09-13-24-46-928",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-13-24-46-928/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 48,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.12xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.12xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":16,"epochs":5,"lr":2e-05,"model_name":"roberta-base"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.12xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=48
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-13-24-46-928/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":16,"epochs":5,"lr":2e-05,"model_name":"roberta-base"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2023-01-09-13-24-46-928","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-13-24-46-928/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":48,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.12xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","16","--epochs","5","--lr","2e-05","--model_name","roberta-base"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=16
# SM_HP_EPOCHS=5
# SM_HP_LR=2e-05
# SM_HP_MODEL_NAME=roberta-base
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 train.py --batch_size 16 --epochs 5 --lr 2e-05 --model_name roberta-base
# Requirement already satisfied: datasets in /opt/conda/lib/python3.6/site-packages (1.6.2)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (2.25.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from datasets) (4.0.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.6/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: huggingface-hub<0.1.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (0.0.8)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.6/site-packages (from datasets) (1.19.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from datasets) (20.9)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.6/site-packages (from datasets) (0.70.11.1)
# Requirement already satisfied: dill in /opt/conda/lib/python3.6/site-packages (from datasets) (0.3.3)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /opt/conda/lib/python3.6/site-packages (from datasets) (4.49.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.6/site-packages (from datasets) (2021.5.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from datasets) (1.1.5)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from datasets) (0.8)
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (4.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->datasets) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->datasets) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.6/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Collecting transformers==4.18
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (4.49.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (2021.4.4)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (0.0.45)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (4.0.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (5.4.1)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (0.8)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (1.19.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (3.0.12)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (20.9)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (2.25.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.6/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.18) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging>=20.0->transformers==4.18) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->transformers==4.18) (3.4.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (1.25.11)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (1.16.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (7.1.2)
# Installing collected packages: tokenizers, huggingface-hub, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.10.3
#     Uninstalling tokenizers-0.10.3:
#       Successfully uninstalled tokenizers-0.10.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.8
#     Uninstalling huggingface-hub-0.0.8:
#       Successfully uninstalled huggingface-hub-0.0.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.6.1
#     Uninstalling transformers-4.6.1:
#       Successfully uninstalled transformers-4.6.1
# Successfully installed huggingface-hub-0.4.0 tokenizers-0.12.1 transformers-4.18.0
# Model will be saved in - /opt/ml/model
# Path to data folder - /opt/ml/input/data/training
# Contents of folder /opt/ml/input/data/training - ['train.csv']
# /opt/ml/input/data/training/train.csv
# Shape of training dataset - (27481, 5)
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following columns in the training set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 21984
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1720
# [2023-01-09 13:29:10.519 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-01-09 13:29:10.553 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-01-09 13:29:10.553 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-01-09 13:29:10.554 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-01-09 13:29:10.554 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2023-01-09 13:29:10.554 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-01-09 13:29:10.653 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.word_embeddings.weight count_params:38603520
# [2023-01-09 13:29:10.653 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.position_embeddings.weight count_params:394752
# [2023-01-09 13:29:10.653 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.token_type_embeddings.weight count_params:768
# [2023-01-09 13:29:10.653 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.653 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.dense.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.654 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.dense.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.dense.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.655 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.dense.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.dense.bias count_params:768
# [2023-01-09 13:29:10.656 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.dense.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.657 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.dense.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.dense.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.658 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.dense.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.dense.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.659 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.dense.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.query.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.query.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.key.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.key.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.value.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.value.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.dense.weight count_params:589824
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.dense.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.intermediate.dense.weight count_params:2359296
# [2023-01-09 13:29:10.660 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.intermediate.dense.bias count_params:3072
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.dense.weight count_params:2359296
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.dense.bias count_params:768
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.LayerNorm.weight count_params:768
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.LayerNorm.bias count_params:768
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.qa_outputs.weight count_params:1536
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:591] name:module.qa_outputs.bias count_params:2
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:593] Total Trainable Params: 124056578
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:425] Monitoring the collections: losses
# [2023-01-09 13:29:10.661 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# NCCL version 2.7.8+cuda11.0
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 1.0661251544952393, 'eval_runtime': 27.8458, 'eval_samples_per_second': 197.409, 'eval_steps_per_second': 3.088, 'epoch': 1.0}
# {'loss': 1.4014, 'learning_rate': 1.4186046511627909e-05, 'epoch': 1.45}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 1.0007996559143066, 'eval_runtime': 27.6206, 'eval_samples_per_second': 199.018, 'eval_steps_per_second': 3.114, 'epoch': 2.0}
# {'loss': 0.9782, 'learning_rate': 8.372093023255815e-06, 'epoch': 2.91}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 0.9550737738609314, 'eval_runtime': 27.9645, 'eval_samples_per_second': 196.57, 'eval_steps_per_second': 3.075, 'epoch': 3.0}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 0.9580963253974915, 'eval_runtime': 27.6389, 'eval_samples_per_second': 198.887, 'eval_steps_per_second': 3.112, 'epoch': 4.0}
# {'loss': 0.8715, 'learning_rate': 2.558139534883721e-06, 'epoch': 4.36}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: text, sentiment, answer_start, textID, selected_text. If text, sentiment, answer_start, textID, selected_text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 0.9592205286026001, 'eval_runtime': 27.4516, 'eval_samples_per_second': 200.243, 'eval_steps_per_second': 3.133, 'epoch': 5.0}
# Training completed. Do not forget to share your model on huggingface.co/models =)
# {'train_runtime': 1758.1882, 'train_samples_per_second': 62.519, 'train_steps_per_second': 0.978, 'train_loss': 1.0525257554165153, 'epoch': 5.0}
# Saving model to -- /opt/ml/model
# Saving model checkpoint to /opt/ml/model
# Configuration saved in /opt/ml/model/config.json
# Model weights saved in /opt/ml/model/pytorch_model.bin
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json
# Training Finished --
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.6.2 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.4.0 which is incompatible.
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# #015Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 481/481 [00:00<00:00, 625kB/s]
# #015Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]#015Downloading:   5%|▍         | 40.0k/878k [00:00<00:03, 224kB/s]#015Downloading:  11%|█         | 96.0k/878k [00:00<00:03, 245kB/s]#015Downloading:  23%|██▎       | 204k/878k [00:00<00:02, 298kB/s] #015Downloading:  49%|████▉     | 428k/878k [00:00<00:01, 386kB/s]#015Downloading: 100%|█████████▉| 876k/878k [00:00<00:00, 517kB/s]#015Downloading: 100%|██████████| 878k/878k [00:00<00:00, 978kB/s]
# #015Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]#015Downloading:   3%|▎         | 12.0k/446k [00:00<00:06, 67.1kB/s]#015Downloading:   6%|▋         | 28.0k/446k [00:00<00:05, 72.5kB/s]#015Downloading:  21%|██        | 92.0k/446k [00:00<00:03, 95.3kB/s]#015Downloading:  45%|████▍     | 200k/446k [00:00<00:01, 128kB/s]  #015Downloading:  95%|█████████▌| 424k/446k [00:00<00:00, 174kB/s]#015Downloading: 100%|██████████| 446k/446k [00:00<00:00, 496kB/s]
# #015Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]#015Downloading:   1%|          | 12.0k/1.29M [00:00<00:19, 67.2kB/s]#015Downloading:   2%|▏         | 28.0k/1.29M [00:00<00:18, 72.5kB/s]#015Downloading:   6%|▋         | 84.0k/1.29M [00:00<00:13, 94.2kB/s]#015Downloading:  15%|█▍        | 196k/1.29M [00:00<00:09, 126kB/s]  #015Downloading:  32%|███▏      | 420k/1.29M [00:00<00:05, 173kB/s]#015Downloading:  66%|██████▌   | 868k/1.29M [00:01<00:01, 240kB/s]#015Downloading: 100%|██████████| 1.29M/1.29M [00:01<00:00, 1.22MB/s]
# ...
# #015 67%|██████▋   | 58/86 [00:18<00:09,  3.10it/s]#033[A
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# #015  0%|          | 0/86 [00:00<?, ?it/s]#033[A
# #015  2%|▏         | 2/86 [00:00<00:13,  6.41it/s]#033[A
# #015  3%|▎         | 3/86 [00:00<00:16,  4.88it/s]#033[A
# #015  5%|▍         | 4/86 [00:01<00:21,  3.90it/s]#033[A
# #015  6%|▌         | 5/86 [00:01<00:20,  3.91it/s]#033[A
# #015  7%|▋         | 6/86 [00:01<00:21,  3.64it/s]#033[A
# #015  8%|▊         | 7/86 [00:01<00:22,  3.48it/s]#033[A
# #015  9%|▉         | 8/86 [00:02<00:23,  3.36it/s]#033[A
# #015 10%|█         | 9/86 [00:02<00:23,  3.31it/s]#033[A
# #015 12%|█▏        | 10/86 [00:02<00:23,  3.28it/s]#033[A
# #015 13%|█▎        | 11/86 [00:03<00:23,  3.22it/s]#033[A
# #015 14%|█▍        | 12/86 [00:03<00:23,  3.22it/s]#033[A
# #015 15%|█▌        | 13/86 [00:03<00:22,  3.20it/s]#033[A
# #015 16%|█▋        | 14/86 [00:04<00:24,  2.98it/s]#033[A
# #015 17%|█▋        | 15/86 [00:04<00:22,  3.22it/s]#033[A
# #015 19%|█▊        | 16/86 [00:04<00:21,  3.21it/s]#033[A
# #015 20%|█▉        | 17/86 [00:05<00:21,  3.19it/s]#033[A
# #015 21%|██        | 18/86 [00:05<00:21,  3.19it/s]#033[A
# #015 22%|██▏       | 19/86 [00:05<00:21,  3.18it/s]#033[A
# #015 23%|██▎       | 20/86 [00:06<00:20,  3.18it/s]#033[A
# #015 24%|██▍       | 21/86 [00:06<00:20,  3.17it/s]#033[A
# #015 26%|██▌       | 22/86 [00:06<00:20,  3.17it/s]#033[A
# #015 27%|██▋       | 23/86 [00:07<00:21,  2.97it/s]#033[A
# #015 28%|██▊       | 24/86 [00:07<00:19,  3.22it/s]#033[A
# #015 29%|██▉       | 25/86 [00:07<00:18,  3.21it/s]#033[A
# #015 30%|███       | 26/86 [00:07<00:18,  3.19it/s]#033[A
# #015 31%|███▏      | 27/86 [00:08<00:18,  3.18it/s]#033[A
# #015 33%|███▎      | 28/86 [00:08<00:18,  3.18it/s]#033[A
# #015 34%|███▎      | 29/86 [00:08<00:18,  3.16it/s]#033[A
# #015 35%|███▍      | 30/86 [00:09<00:17,  3.16it/s]#033[A
# #015 36%|███▌      | 31/86 [00:09<00:17,  3.17it/s]#033[A
# #015 37%|███▋      | 32/86 [00:09<00:17,  3.15it/s]#033[A
# #015 38%|███▊      | 33/86 [00:10<00:18,  2.94it/s]#033[A
# #015 40%|███▉      | 34/86 [00:10<00:16,  3.18it/s]#033[A
# #015 41%|████      | 35/86 [00:10<00:16,  3.17it/s]#033[A
# #015 42%|████▏     | 36/86 [00:11<00:15,  3.17it/s]#033[A
# #015 43%|████▎     | 37/86 [00:11<00:15,  3.15it/s]#033[A
# #015 44%|████▍     | 38/86 [00:11<00:15,  3.15it/s]#033[A
# #015 45%|████▌     | 39/86 [00:12<00:14,  3.16it/s]#033[A
# #015 47%|████▋     | 40/86 [00:12<00:14,  3.14it/s]#033[A
# #015 48%|████▊     | 41/86 [00:12<00:14,  3.14it/s]#033[A
# #015 49%|████▉     | 42/86 [00:13<00:15,  2.93it/s]#033[A
# #015 50%|█████     | 43/86 [00:13<00:13,  3.21it/s]#033[A
# #015 51%|█████     | 44/86 [00:13<00:13,  3.19it/s]#033[A
# #015 52%|█████▏    | 45/86 [00:13<00:12,  3.18it/s]#033[A
# #015 53%|█████▎    | 46/86 [00:14<00:12,  3.17it/s]#033[A
# #015 55%|█████▍    | 47/86 [00:14<00:12,  3.15it/s]#033[A
# #015 56%|█████▌    | 48/86 [00:14<00:12,  3.15it/s]#033[A
# #015 57%|█████▋    | 49/86 [00:15<00:11,  3.15it/s]#033[A
# #015 58%|█████▊    | 50/86 [00:15<00:11,  3.15it/s]#033[A
# #015 59%|█████▉    | 51/86 [00:15<00:11,  3.13it/s]#033[A
# #015 60%|██████    | 52/86 [00:16<00:10,  3.13it/s]#033[A
# #015 62%|██████▏   | 53/86 [00:16<00:11,  2.92it/s]#033[A
# #015 63%|██████▎   | 54/86 [00:16<00:09,  3.21it/s]#033[A
# #015 64%|██████▍   | 55/86 [00:17<00:09,  3.18it/s]#033[A
# #015 65%|██████▌   | 56/86 [00:17<00:09,  3.17it/s]#033[A
# #015 66%|██████▋   | 57/86 [00:17<00:09,  3.17it/s]#033[A
# #015 67%|██████▋   | 58/86 [00:18<00:08,  3.16it/s]#033[A
# #015 69%|██████▊   | 59/86 [00:18<00:08,  3.14it/s]#033[A
# #015 70%|██████▉   | 60/86 [00:18<00:08,  3.14it/s]#033[A
# #015 71%|███████   | 61/86 [00:19<00:07,  3.15it/s]#033[A
# #015 72%|███████▏  | 62/86 [00:19<00:07,  3.14it/s]#033[A
# #015 73%|███████▎  | 63/86 [00:19<00:07,  3.13it/s]#033[A
# #015 74%|███████▍  | 64/86 [00:20<00:07,  3.14it/s]#033[A
# #015 76%|███████▌  | 65/86 [00:20<00:07,  2.90it/s]#033[A
# #015 77%|███████▋  | 66/86 [00:20<00:06,  3.15it/s]#033[A
# #015 78%|███████▊  | 67/86 [00:21<00:06,  3.13it/s]#033[A
# #015 79%|███████▉  | 68/86 [00:21<00:05,  3.12it/s]#033[A
# #015 80%|████████  | 69/86 [00:21<00:05,  3.12it/s]#033[A
# #015 81%|████████▏ | 70/86 [00:21<00:05,  3.13it/s]#033[A
# #015 83%|████████▎ | 71/86 [00:22<00:04,  3.13it/s]#033[A
# #015 84%|████████▎ | 72/86 [00:22<00:04,  3.12it/s]#033[A
# #015 85%|████████▍ | 73/86 [00:22<00:04,  3.12it/s]#033[A
# #015 86%|████████▌ | 74/86 [00:23<00:03,  3.12it/s]#033[A
# #015 87%|████████▋ | 75/86 [00:23<00:03,  3.12it/s]#033[A
# #015 88%|████████▊ | 76/86 [00:23<00:03,  3.13it/s]#033[A
# #015 90%|████████▉ | 77/86 [00:24<00:03,  2.87it/s]#033[A
# #015 91%|█████████ | 78/86 [00:24<00:02,  3.13it/s]#033[A
# #015 92%|█████████▏| 79/86 [00:24<00:02,  3.12it/s]#033[A
# #015 93%|█████████▎| 80/86 [00:25<00:01,  3.12it/s]#033[A
# #015 94%|█████████▍| 81/86 [00:25<00:01,  3.11it/s]#033[A
# #015 95%|█████████▌| 82/86 [00:25<00:01,  3.10it/s]#033[A
# #015 97%|█████████▋| 83/86 [00:26<00:00,  3.10it/s]#033[A
# #015 98%|█████████▊| 84/86 [00:26<00:00,  3.12it/s]#033[A
# #015 99%|█████████▉| 85/86 [00:26<00:00,  3.12it/s]#033[A
# #015100%|██████████| 86/86 [00:27<00:00,  3.13it/s]#033[A#015                                                   #015
# #015                                               #015#033[A#015100%|██████████| 1720/1720 [29:18<00:00,  1.22it/s]
# #015100%|██████████| 86/86 [00:27<00:00,  3.13it/s]#033[A
# #015                                               #033[A
# Training completed. Do not forget to share your model on huggingface.co/models =)
# #015                                                   #015#015100%|██████████| 1720/1720 [29:18<00:00,  1.22it/s]#015100%|██████████| 1720/1720 [29:18<00:00,  1.02s/it]
# Saving model checkpoint to /opt/ml/model
# Configuration saved in /opt/ml/model/config.json
# Model weights saved in /opt/ml/model/pytorch_model.bin
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json
# 2023-01-09 13:58:40 Uploading - Uploading generated training model
# 2023-01-09 13:59:40 Completed - Training job completed
# ProfilerReport-1673270687: IssuesFound
# Training seconds: 1998
# Billable seconds: 1998

# %% [markdown]
# ---
#
# # Generate Endpoint for online inference

# %%
predictor = huggingface_estimator.deploy(
    initial_instance_count=1, instance_type="ml.c5.xlarge"
)
# Out:
# ----!

# %%
sentences = [
    "Tommy is ridiculous but a good dog.",
    "Day went poor. Night was fantastic.",
    "What a slave this beautiful boy is.",
    "Chelsea lost inspite of their remarkable play.",
]
for sentence in sentences:
    for sentiment in ["positive", "negative"]:
        data = {"context": sentence, "question": sentiment}
        print("Sentence ", sentence)
        print("Sentiment ", sentiment)
        print(predictor.predict(data))
# Out:
# Sentence  Tommy is ridiculous but a good dog.
# Sentiment  positive
# {'score': 0.3929924964904785, 'start': 26, 'end': 35, 'answer': 'good dog.'}
# Sentence  Tommy is ridiculous but a good dog.
# Sentiment  negative
# {'score': 0.3233451843261719, 'start': 9, 'end': 19, 'answer': 'ridiculous'}
# Sentence  Day went poor. Night was fantastic.
# Sentiment  positive
# {'score': 0.7062358260154724, 'start': 25, 'end': 35, 'answer': 'fantastic.'}
# Sentence  Day went poor. Night was fantastic.
# Sentiment  negative
# {'score': 0.3059115707874298, 'start': 9, 'end': 14, 'answer': 'poor.'}
# Sentence  What a slave this beautiful boy is.
# Sentiment  positive
# {'score': 0.4300776720046997, 'start': 18, 'end': 35, 'answer': 'beautiful boy is.'}
# Sentence  What a slave this beautiful boy is.
# Sentiment  negative
# {'score': 0.3133225739002228, 'start': 7, 'end': 12, 'answer': 'slave'}
# Sentence  Chelsea lost inspite of their remarkable play.
# Sentiment  positive
# {'score': 0.40357911586761475, 'start': 30, 'end': 40, 'answer': 'remarkable'}
# Sentence  Chelsea lost inspite of their remarkable play.
# Sentiment  negative
# {'score': 0.2853446900844574, 'start': 8, 'end': 12, 'answer': 'lost'}
