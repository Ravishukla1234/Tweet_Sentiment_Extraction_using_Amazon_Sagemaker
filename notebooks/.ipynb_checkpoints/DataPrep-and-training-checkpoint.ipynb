# %% [markdown]
# # Data Preparation and Training
#
# In this notebook, we are going to run question answer training on Amazon Sagemaker.

# %% [markdown]
# ---
#
# # Data Preparation

# %% [markdown]
# ## Load required libraries

# %%
import pandas as pd
import numpy as np
import os

import sagemaker
import boto3
import json

import sagemaker
from sagemaker import get_execution_role
from sagemaker.huggingface import HuggingFace

from sagemaker.s3 import S3Downloader
from sagemaker.s3 import S3Uploader

data_dir = "../inputs"

sagemaker_session = sagemaker.Session()
region = sagemaker_session.boto_region_name
role = get_execution_role()
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ---
#
# # Train Bert model using Amazon Sagemaker

# %%
train_file_location = f"{data_dir}/train.csv"
bucket = sagemaker_session.default_bucket()
prefix = "sentiment_extraction/data"


inputs = S3Uploader.upload(train_file_location, "s3://{}/{}".format(bucket, prefix))

inputs =  "s3://{}/{}".format(bucket, prefix)
print(inputs)
# Out:
# s3://sagemaker-ap-south-1-296512243111/sentiment_extraction/data

# %%
hyperparameters={
                 
    "model_name": "roberta-base",
    "batch_size": 16,
    "epochs": 5 ,
    "lr" : 2e-5,
                 }

# %%
local_script_location = "../src"
hub = {
  'HF_TASK':'question-answering'     ## NLP task you want to use for predictions
}
huggingface_estimator = HuggingFace(
        entry_point='train.py',
        source_dir=local_script_location,
        env=hub, 
        instance_type='ml.g4dn.12xlarge',
#         instance_type='ml.p2.xlarge', 
        instance_count=1,
        role=role,
        transformers_version='4.6',
        pytorch_version='1.7',
        py_version='py36',
        hyperparameters = hyperparameters
)
huggingface_estimator.fit(inputs)
# Out:
# 2023-01-09 11:45:05 Starting - Starting the training job...
# 2023-01-09 11:45:34 Starting - Preparing the instances for trainingProfilerReport-1673264705: InProgress
# .........
# 2023-01-09 11:46:54 Downloading - Downloading input data
# 2023-01-09 11:46:54 Training - Downloading the training image.........
# 2023-01-09 11:48:34 Training - Training image download completed. Training in progress.....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2023-01-09 11:49:09,105 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2023-01-09 11:49:09,152 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2023-01-09 11:49:09,154 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2023-01-09 11:49:09,448 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 16,
#         "epochs": 5,
#         "lr": 2e-05,
#         "model_name": "roberta-base"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2023-01-09-11-45-05-214",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-11-45-05-214/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 48,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.12xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.12xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":16,"epochs":5,"lr":2e-05,"model_name":"roberta-base"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.12xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=48
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-11-45-05-214/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":16,"epochs":5,"lr":2e-05,"model_name":"roberta-base"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2023-01-09-11-45-05-214","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-south-1-296512243111/huggingface-pytorch-training-2023-01-09-11-45-05-214/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":48,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.12xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.12xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","16","--epochs","5","--lr","2e-05","--model_name","roberta-base"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH_SIZE=16
# SM_HP_EPOCHS=5
# SM_HP_LR=2e-05
# SM_HP_MODEL_NAME=roberta-base
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 train.py --batch_size 16 --epochs 5 --lr 2e-05 --model_name roberta-base
# Requirement already satisfied: datasets in /opt/conda/lib/python3.6/site-packages (1.6.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.6/site-packages (from datasets) (2021.5.0)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /opt/conda/lib/python3.6/site-packages (from datasets) (4.49.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from datasets) (20.9)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from datasets) (0.8)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.6/site-packages (from datasets) (1.19.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (2.25.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from datasets) (1.1.5)
# Requirement already satisfied: dill in /opt/conda/lib/python3.6/site-packages (from datasets) (0.3.3)
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (4.0.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.6/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.6/site-packages (from datasets) (0.70.11.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from datasets) (4.0.1)
# Requirement already satisfied: huggingface-hub<0.1.0 in /opt/conda/lib/python3.6/site-packages (from datasets) (0.0.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from huggingface-hub<0.1.0->datasets) (3.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->datasets) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->datasets) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.6/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)
# Collecting transformers==4.18
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (2021.4.4)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (0.0.45)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (5.4.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (3.0.12)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (4.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (2.25.1)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (0.8)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (1.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.6/site-packages (from transformers==4.18) (20.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.6/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.18) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging>=20.0->transformers==4.18) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->transformers==4.18) (3.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.18) (3.0.4)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (1.16.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.18) (7.1.2)
# Installing collected packages: tokenizers, huggingface-hub, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.10.3
#     Uninstalling tokenizers-0.10.3:
#       Successfully uninstalled tokenizers-0.10.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.8
#     Uninstalling huggingface-hub-0.0.8:
#       Successfully uninstalled huggingface-hub-0.0.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.6.1
#     Uninstalling transformers-4.6.1:
#       Successfully uninstalled transformers-4.6.1
# Successfully installed huggingface-hub-0.4.0 tokenizers-0.12.1 transformers-4.18.0
# Model will be saved in - /opt/ml/model
# Path to data folder - /opt/ml/input/data/training
# Contents of folder /opt/ml/input/data/training - ['train.csv']
# /opt/ml/input/data/training/train.csv
# Shape of training dataset - (27481, 5)
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following columns in the training set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running training *****
#   Num examples = 21984
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1720
# [2023-01-09 11:49:47.012 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-01-09 11:49:47.046 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2023-01-09 11:49:47.046 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2023-01-09 11:49:47.046 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2023-01-09 11:49:47.047 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2023-01-09 11:49:47.047 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2023-01-09 11:49:47.131 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.word_embeddings.weight count_params:38603520
# [2023-01-09 11:49:47.131 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.position_embeddings.weight count_params:394752
# [2023-01-09 11:49:47.131 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.token_type_embeddings.weight count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.embeddings.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.dense.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.0.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.132 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.dense.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.1.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.dense.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.2.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.133 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.dense.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.3.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.dense.bias count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.134 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.4.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.dense.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.5.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.135 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.dense.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.6.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.dense.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.7.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.136 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.dense.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.8.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.dense.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.9.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.137 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.dense.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.10.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.query.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.query.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.key.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.key.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.value.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.self.value.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.dense.weight count_params:589824
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.dense.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.attention.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.intermediate.dense.weight count_params:2359296
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.intermediate.dense.bias count_params:3072
# [2023-01-09 11:49:47.138 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.dense.weight count_params:2359296
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.dense.bias count_params:768
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.LayerNorm.weight count_params:768
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:591] name:module.roberta.encoder.layer.11.output.LayerNorm.bias count_params:768
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:591] name:module.qa_outputs.weight count_params:1536
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:591] name:module.qa_outputs.bias count_params:2
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:593] Total Trainable Params: 124056578
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:425] Monitoring the collections: losses
# [2023-01-09 11:49:47.139 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# NCCL version 2.7.8+cuda11.0
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 1.0898241996765137, 'eval_runtime': 27.1365, 'eval_samples_per_second': 202.569, 'eval_steps_per_second': 3.169, 'epoch': 1.0}
# {'loss': 1.4402, 'learning_rate': 1.4186046511627909e-05, 'epoch': 1.45}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 1.0108500719070435, 'eval_runtime': 27.1544, 'eval_samples_per_second': 202.435, 'eval_steps_per_second': 3.167, 'epoch': 2.0}
# {'loss': 0.9945, 'learning_rate': 8.372093023255815e-06, 'epoch': 2.91}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 0.9674615263938904, 'eval_runtime': 25.8537, 'eval_samples_per_second': 212.62, 'eval_steps_per_second': 3.326, 'epoch': 3.0}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# {'eval_loss': 0.9757025837898254, 'eval_runtime': 25.7923, 'eval_samples_per_second': 213.126, 'eval_steps_per_second': 3.334, 'epoch': 4.0}
# {'loss': 0.8842, 'learning_rate': 2.558139534883721e-06, 'epoch': 4.36}
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: answer_start, sentiment, textID, selected_text, text. If answer_start, sentiment, textID, selected_text, text are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
#
# 2023-01-09 12:17:55 Uploading - Uploading generated training model{'eval_loss': 0.9693019986152649, 'eval_runtime': 26.8238, 'eval_samples_per_second': 204.93, 'eval_steps_per_second': 3.206, 'epoch': 5.0}
# Training completed. Do not forget to share your model on huggingface.co/models =)
# {'train_runtime': 1684.1879, 'train_samples_per_second': 65.266, 'train_steps_per_second': 1.021, 'train_loss': 1.074010414300963, 'epoch': 5.0}
# Saving model to -- /opt/ml/model
# Saving model checkpoint to /opt/ml/model
# Configuration saved in /opt/ml/model/config.json
# Model weights saved in /opt/ml/model/pytorch_model.bin
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json
# Training Finished --
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.6.2 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.4.0 which is incompatible.
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# #015Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]#015Downloading: 100%|██████████| 481/481 [00:00<00:00, 597kB/s]
# #015Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]#015Downloading:   1%|▏         | 12.0k/878k [00:00<00:13, 67.2kB/s]#015Downloading:   3%|▎         | 28.0k/878k [00:00<00:11, 72.6kB/s]#015Downloading:  11%|█         | 96.0k/878k [00:00<00:08, 95.8kB/s]#015Downloading:  24%|██▎       | 208k/878k [00:00<00:05, 128kB/s]  #015Downloading:  49%|████▉     | 432k/878k [00:00<00:02, 176kB/s]#015Downloading: 100%|██████████| 878k/878k [00:00<00:00, 935kB/s]
# #015Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]#015Downloading:   3%|▎         | 12.0k/446k [00:00<00:06, 67.4kB/s]#015Downloading:   6%|▋         | 28.0k/446k [00:00<00:05, 72.7kB/s]#015Downloading:  22%|██▏       | 96.0k/446k [00:00<00:03, 96.0kB/s]#015Downloading:  47%|████▋     | 208k/446k [00:00<00:01, 129kB/s]  #015Downloading:  93%|█████████▎| 416k/446k [00:00<00:00, 175kB/s]#015Downloading: 100%|██████████| 446k/446k [00:00<00:00, 497kB/s]
# #015Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]#015Downloading:   0%|          | 4.00k/1.29M [00:00<01:00, 22.4kB/s]#015Downloading:   2%|▏         | 32.0k/1.29M [00:00<00:43, 30.2kB/s]#015Downloading:   7%|▋         | 96.0k/1.29M [00:00<00:30, 41.6kB/s]#015Downloading:  16%|█▌        | 208k/1.29M [00:00<00:19, 57.8kB/s] #015Downloading:  33%|███▎      | 432k/1.29M [00:00<00:11, 80.9kB/s]#015Downloading:  66%|██████▋   | 880k/1.29M [00:01<00:03, 114kB/s] #015Downloading: 100%|██████████| 1.29M/1.29M [00:01<00:00, 1.22MB/s]
# ...
# #015 66%|██████▋   | 57/86 [00:16<00:08,  3.34it/s]#033[A
# #015 67%|██████▋   | 58/86 [00:17<00:09,  3.07it/s]#033[A
# #015 69%|██████▊   | 59/86 [00:17<00:07,  3.42it/s]#033[A
# #015 70%|██████▉   | 60/86 [00:17<00:07,  3.40it/s]#033[A
# #015 71%|███████   | 61/86 [00:17<00:07,  3.38it/s]#033[A
# #015 72%|███████▏  | 62/86 [00:18<00:07,  3.37it/s]#033[A
# #015 73%|███████▎  | 63/86 [00:18<00:06,  3.35it/s]#033[A
# #015 74%|███████▍  | 64/86 [00:18<00:06,  3.35it/s]#033[A
# #015 76%|███████▌  | 65/86 [00:19<00:06,  3.35it/s]#033[A
# #015 77%|███████▋  | 66/86 [00:19<00:05,  3.34it/s]#033[A
# #015 78%|███████▊  | 67/86 [00:19<00:05,  3.34it/s]#033[A
# #015 79%|███████▉  | 68/86 [00:20<00:05,  3.33it/s]#033[A
# #015 80%|████████  | 69/86 [00:20<00:05,  3.33it/s]#033[A
# #015 81%|████████▏ | 70/86 [00:20<00:05,  3.07it/s]#033[A
# #015 83%|████████▎ | 71/86 [00:20<00:04,  3.42it/s]#033[A
# #015 84%|████████▎ | 72/86 [00:21<00:04,  3.38it/s]#033[A
# #015 85%|████████▍ | 73/86 [00:21<00:03,  3.36it/s]#033[A
# #015 86%|████████▌ | 74/86 [00:21<00:03,  3.34it/s]#033[A
# #015 87%|████████▋ | 75/86 [00:22<00:03,  3.35it/s]#033[A
# #015 88%|████████▊ | 76/86 [00:22<00:02,  3.33it/s]#033[A
# #015 90%|████████▉ | 77/86 [00:22<00:02,  3.33it/s]#033[A
# #015 91%|█████████ | 78/86 [00:23<00:02,  3.33it/s]#033[A
# #015 92%|█████████▏| 79/86 [00:23<00:02,  3.34it/s]#033[A
# #015 93%|█████████▎| 80/86 [00:23<00:01,  3.33it/s]#033[A
# #015 94%|█████████▍| 81/86 [00:23<00:01,  3.33it/s]#033[A
# #015 95%|█████████▌| 82/86 [00:24<00:01,  3.33it/s]#033[A
# #015 97%|█████████▋| 83/86 [00:24<00:00,  3.05it/s]#033[A
# #015 98%|█████████▊| 84/86 [00:24<00:00,  3.43it/s]#033[A
# #015 99%|█████████▉| 85/86 [00:25<00:00,  3.40it/s]#033[A
# #015100%|██████████| 86/86 [00:25<00:00,  3.37it/s]#033[A#015                                                   #015
# #015                                               #015#033[A#015 80%|████████  | 1376/1720 [22:23<04:28,  1.28it/s]
# #015100%|██████████| 86/86 [00:25<00:00,  3.37it/s]#033[A
# #015                                               #033[A#015 80%|████████  | 1377/1720 [22:25<49:29,  8.66s/it]#015 80%|████████  | 1378/1720 [22:25<36:03,  6.32s/it]#015 80%|████████  | 1379/1720 [22:26<26:40,  4.69s/it]#015 80%|████████  | 1380/1720 [22:27<20:07,  3.55s/it]#015 80%|████████  | 1381/1720 [22:28<15:32,  2.75s/it]#015 80%|████████  | 1382/1720 [22:29<12:20,  2.19s/it]#015 80%|████████  | 1383/1720 [22:30<10:05,  1.80s/it]#015 80%|████████  | 1384/1720 [22:31<08:31,  1.52s/it]#015 81%|████████  | 1385/1720 [22:32<07:26,  1.33s/it]#015 81%|████████  | 1386/1720 [22:32<06:39,  1.20s/it]#015 81%|████████  | 1387/1720 [22:33<06:07,  1.10s/it]#015 81%|████████  | 1388/1720 [22:34<05:44,  1.04s/it]#015 81%|████████  | 1389/1720 [22:35<05:28,  1.01it/s]#015 81%|████████  | 1390/1720 [22:36<05:22,  1.02it/s]#015 81%|████████  | 1391/1720 [22:37<05:11,  1.05it/s]#015 81%|████████  | 1392/1720 [22:38<05:04,  1.08it/s]#015 81%|████████  | 1393/1720 [22:39<04:59,  1.09it/s]#015 81%|████████  | 1394/1720 [22:40<04:55,  1.10it/s]#015 81%|████████  | 1395/1720 [22:40<04:52,  1.11it/s]#015 81%|████████  | 1396/1720 [22:41<04:50,  1.12it/s]#015 81%|████████  | 1397/1720 [22:42<04:47,  1.12it/s]#015 81%|████████▏ | 1398/1720 [22:43<04:46,  1.12it/s]#015 81%|████████▏ | 1399/1720 [22:44<04:45,  1.12it/s]#015 81%|████████▏ | 1400/1720 [22:45<04:44,  1.12it/s]#015 81%|████████▏ | 1401/1720 [22:46<04:43,  1.13it/s]#015 82%|████████▏ | 1402/1720 [22:47<04:42,  1.13it/s]#015 82%|████████▏ | 1403/1720 [22:48<04:41,  1.13it/s]#015 82%|████████▏ | 1404/1720 [22:48<04:40,  1.13it/s]#015 82%|████████▏ | 1405/1720 [22:49<04:39,  1.13it/s]#015 82%|████████▏ | 1406/1720 [22:50<04:38,  1.13it/s]#015 82%|████████▏ | 1407/1720 [22:51<04:38,  1.12it/s]#015 82%|████████▏ | 1408/1720 [22:52<04:37,  1.12it/s]#015 82%|████████▏ | 1409/1720 [22:53<04:36,  1.12it/s]#015 82%|████████▏ | 1410/1720 [22:54<04:36,  1.12it/s]#015 82%|████████▏ | 1411/1720 [22:55<04:35,  1.12it/s]#015 82%|████████▏ | 1412/1720 [22:56<04:34,  1.12it/s]#015 82%|████████▏ | 1413/1720 [22:56<04:33,  1.12it/s]#015 82%|████████▏ | 1414/1720 [22:57<04:32,  1.12it/s]#015 82%|████████▏ | 1415/1720 [22:58<04:31,  1.13it/s]#015 82%|████████▏ | 1416/1720 [22:59<04:30,  1.12it/s]#015 82%|████████▏ | 1417/1720 [23:00<04:30,  1.12it/s]#015 82%|████████▏ | 1418/1720 [23:01<04:29,  1.12it/s]#015 82%|████████▎ | 1419/1720 [23:02<04:28,  1.12it/s]#015 83%|████████▎ | 1420/1720 [23:03<04:26,  1.12it/s]#015 83%|████████▎ | 1421/1720 [23:04<04:26,  1.12it/s]#015 83%|████████▎ | 1422/1720 [23:04<04:25,  1.12it/s]#015 83%|████████▎ | 1423/1720 [23:05<04:24,  1.12it/s]#015 83%|████████▎ | 1424/1720 [23:06<04:23,  1.12it/s]#015 83%|████████▎ | 1425/1720 [23:07<04:22,  1.12it/s]#015 83%|████████▎ | 1426/1720 [23:08<04:22,  1.12it/s]#015 83%|████████▎ | 1427/1720 [23:09<04:22,  1.12it/s]#015 83%|████████▎ | 1428/1720 [23:10<04:21,  1.12it/s]#015 83%|████████▎ | 1429/1720 [23:11<04:20,  1.12it/s]#015 83%|████████▎ | 1430/1720 [23:12<04:20,  1.12it/s]#015 83%|████████▎ | 1431/1720 [23:13<04:19,  1.12it/s]#015 83%|████████▎ | 1432/1720 [23:13<04:18,  1.11it/s]#015 83%|████████▎ | 1433/1720 [23:14<04:17,  1.12it/s]#015 83%|████████▎ | 1434/1720 [23:15<04:16,  1.12it/s]#015 83%|████████▎ | 1435/1720 [23:16<04:16,  1.11it/s]#015 83%|████████▎ | 1436/1720 [23:17<04:14,  1.12it/s]#015 84%|████████▎ | 1437/1720 [23:18<04:14,  1.11it/s]#015 84%|████████▎ | 1438/1720 [23:19<04:13,  1.11it/s]#015 84%|████████▎ | 1439/1720 [23:20<04:12,  1.11it/s]#015 84%|████████▎ | 1440/1720 [23:21<04:11,  1.11it/s]#015 84%|████████▍ | 1441/1720 [23:22<04:11,  1.11it/s]#015 84%|████████▍ | 1442/1720 [23:22<04:10,  1.11it/s]#015 84%|████████▍ | 1443/1720 [23:23<04:09,  1.11it/s]#015 84%|████████▍ | 1444/1720 [23:24<04:08,  1.11it/s]#015 84%|████████▍ | 1445/1720 [23:25<04:08,  1.11it/s]#015 84%|████████▍ | 1446/1720 [23:26<04:06,  1.11it/s]#015 84%|████████▍ | 1447/1720 [23:27<04:06,  1.11it/s]#015 84%|████████▍ | 1448/1720 [23:28< ...
# █████████▎| 1608/1720 [25:54<01:43,  1.08it/s]#015 94%|█████████▎| 1609/1720 [25:55<01:42,  1.09it/s]#015 94%|█████████▎| 1610/1720 [25:56<01:41,  1.09it/s]#015 94%|█████████▎| 1611/1720 [25:57<01:40,  1.09it/s]#015 94%|█████████▎| 1612/1720 [25:58<01:39,  1.09it/s]#015 94%|█████████▍| 1613/1720 [25:59<01:38,  1.08it/s]#015 94%|█████████▍| 1614/1720 [26:00<01:37,  1.08it/s]#015 94%|█████████▍| 1615/1720 [26:00<01:37,  1.08it/s]#015 94%|█████████▍| 1616/1720 [26:01<01:35,  1.08it/s]#015 94%|█████████▍| 1617/1720 [26:02<01:35,  1.08it/s]#015 94%|█████████▍| 1618/1720 [26:03<01:34,  1.08it/s]#015 94%|█████████▍| 1619/1720 [26:04<01:33,  1.08it/s]#015 94%|█████████▍| 1620/1720 [26:05<01:32,  1.08it/s]#015 94%|█████████▍| 1621/1720 [26:06<01:31,  1.08it/s]#015 94%|█████████▍| 1622/1720 [26:07<01:30,  1.08it/s]#015 94%|█████████▍| 1623/1720 [26:08<01:29,  1.08it/s]#015 94%|█████████▍| 1624/1720 [26:09<01:28,  1.08it/s]#015 94%|█████████▍| 1625/1720 [26:10<01:27,  1.08it/s]#015 95%|█████████▍| 1626/1720 [26:11<01:26,  1.08it/s]#015 95%|█████████▍| 1627/1720 [26:12<01:25,  1.08it/s]#015 95%|█████████▍| 1628/1720 [26:13<01:25,  1.08it/s]#015 95%|█████████▍| 1629/1720 [26:13<01:23,  1.08it/s]#015 95%|█████████▍| 1630/1720 [26:14<01:23,  1.08it/s]#015 95%|█████████▍| 1631/1720 [26:15<01:22,  1.08it/s]#015 95%|█████████▍| 1632/1720 [26:16<01:21,  1.08it/s]#015 95%|█████████▍| 1633/1720 [26:17<01:20,  1.08it/s]#015 95%|█████████▌| 1634/1720 [26:18<01:19,  1.08it/s]#015 95%|█████████▌| 1635/1720 [26:19<01:18,  1.08it/s]#015 95%|█████████▌| 1636/1720 [26:20<01:17,  1.08it/s]#015 95%|█████████▌| 1637/1720 [26:21<01:16,  1.08it/s]#015 95%|█████████▌| 1638/1720 [26:22<01:15,  1.08it/s]#015 95%|█████████▌| 1639/1720 [26:23<01:14,  1.08it/s]#015 95%|█████████▌| 1640/1720 [26:24<01:14,  1.08it/s]#015 95%|█████████▌| 1641/1720 [26:25<01:13,  1.08it/s]#015 95%|█████████▌| 1642/1720 [26:25<01:12,  1.08it/s]#015 96%|█████████▌| 1643/1720 [26:26<01:11,  1.08it/s]#015 96%|█████████▌| 1644/1720 [26:27<01:10,  1.08it/s]#015 96%|█████████▌| 1645/1720 [26:28<01:09,  1.08it/s]#015 96%|█████████▌| 1646/1720 [26:29<01:08,  1.08it/s]#015 96%|█████████▌| 1647/1720 [26:30<01:07,  1.08it/s]#015 96%|█████████▌| 1648/1720 [26:31<01:06,  1.08it/s]#015 96%|█████████▌| 1649/1720 [26:32<01:05,  1.08it/s]#015 96%|█████████▌| 1650/1720 [26:33<01:04,  1.08it/s]#015 96%|█████████▌| 1651/1720 [26:34<01:03,  1.08it/s]#015 96%|█████████▌| 1652/1720 [26:35<01:02,  1.08it/s]#015 96%|█████████▌| 1653/1720 [26:36<01:01,  1.08it/s]#015 96%|█████████▌| 1654/1720 [26:37<01:00,  1.08it/s]#015 96%|█████████▌| 1655/1720 [26:37<00:59,  1.08it/s]#015 96%|█████████▋| 1656/1720 [26:38<00:59,  1.08it/s]#015 96%|█████████▋| 1657/1720 [26:39<00:58,  1.08it/s]#015 96%|█████████▋| 1658/1720 [26:40<00:57,  1.08it/s]#015 96%|█████████▋| 1659/1720 [26:41<00:56,  1.08it/s]#015 97%|█████████▋| 1660/1720 [26:42<00:55,  1.08it/s]#015 97%|█████████▋| 1661/1720 [26:43<00:54,  1.08it/s]#015 97%|█████████▋| 1662/1720 [26:44<00:53,  1.08it/s]#015 97%|█████████▋| 1663/1720 [26:45<00:52,  1.08it/s]#015 97%|█████████▋| 1664/1720 [26:46<00:51,  1.08it/s]#015 97%|█████████▋| 1665/1720 [26:47<00:50,  1.08it/s]#015 97%|█████████▋| 1666/1720 [26:48<00:49,  1.08it/s]#015 97%|█████████▋| 1667/1720 [26:49<00:49,  1.08it/s]#015 97%|█████████▋| 1668/1720 [26:49<00:48,  1.08it/s]#015 97%|█████████▋| 1669/1720 [26:50<00:47,  1.08it/s]#015 97%|█████████▋| 1670/1720 [26:51<00:46,  1.08it/s]#015 97%|█████████▋| 1671/1720 [26:52<00:45,  1.08it/s]#015 97%|█████████▋| 1672/1720 [26:53<00:44,  1.08it/s]#015 97%|█████████▋| 1673/1720 [26:54<00:43,  1.08it/s]#015 97%|█████████▋| 1674/1720 [26:55<00:42,  1.08it/s]#015 97%|█████████▋| 1675/1720 [26:56<00:42,  1.06it/s]#015 97%|█████████▋| 1676/1720 [26:57<00:41,  1.07it/s]#015 98%|█████████▊| 1677/1720 [26:58<00:40,  1.07it/s]#015 98%|█████████▊| 1678/1720 [26:59<00:39,  1.08it/s]#015 98%|█████████▊| 1679/1720 [27:00<00:37,  1.08it/s]#015 98%|█████████▊| 1680/1720 [27:01<00:37,  1.0 ...
# ***** Running Evaluation *****
#   Num examples = 5497
#   Batch size = 16
# #015  0%|          | 0/86 [00:00<?, ?it/s]#033[A
# #015  2%|▏         | 2/86 [00:00<00:13,  6.46it/s]#033[A
# #015  3%|▎         | 3/86 [00:00<00:16,  4.97it/s]#033[A
# #015  5%|▍         | 4/86 [00:00<00:19,  4.26it/s]#033[A
# #015  6%|▌         | 5/86 [00:01<00:20,  3.88it/s]#033[A
# #015  7%|▋         | 6/86 [00:01<00:21,  3.66it/s]#033[A
# #015  8%|▊         | 7/86 [00:01<00:22,  3.51it/s]#033[A
# #015  9%|▉         | 8/86 [00:02<00:22,  3.42it/s]#033[A
# #015 10%|█         | 9/86 [00:02<00:22,  3.36it/s]#033[A
# #015 12%|█▏        | 10/86 [00:02<00:24,  3.10it/s]#033[A
# #015 13%|█▎        | 11/86 [00:03<00:22,  3.35it/s]#033[A
# #015 14%|█▍        | 12/86 [00:03<00:22,  3.31it/s]#033[A
# #015 15%|█▌        | 13/86 [00:03<00:22,  3.27it/s]#033[A
# #015 16%|█▋        | 14/86 [00:04<00:22,  3.26it/s]#033[A
# #015 17%|█▋        | 15/86 [00:04<00:21,  3.23it/s]#033[A
# #015 19%|█▊        | 16/86 [00:04<00:21,  3.24it/s]#033[A
# #015 20%|█▉        | 17/86 [00:04<00:21,  3.24it/s]#033[A
# #015 21%|██        | 18/86 [00:05<00:21,  3.23it/s]#033[A
# #015 22%|██▏       | 19/86 [00:05<00:22,  3.03it/s]#033[A
# #015 23%|██▎       | 20/86 [00:05<00:20,  3.29it/s]#033[A
# #015 24%|██▍       | 21/86 [00:06<00:19,  3.27it/s]#033[A
# #015 26%|██▌       | 22/86 [00:06<00:19,  3.25it/s]#033[A
# #015 27%|██▋       | 23/86 [00:06<00:19,  3.25it/s]#033[A
# #015 28%|██▊       | 24/86 [00:07<00:19,  3.25it/s]#033[A
# #015 29%|██▉       | 25/86 [00:07<00:18,  3.24it/s]#033[A
# #015 30%|███       | 26/86 [00:07<00:18,  3.23it/s]#033[A
# #015 31%|███▏      | 27/86 [00:08<00:18,  3.23it/s]#033[A
# #015 33%|███▎      | 28/86 [00:08<00:17,  3.23it/s]#033[A
# #015 34%|███▎      | 29/86 [00:08<00:18,  3.01it/s]#033[A
# #015 35%|███▍      | 30/86 [00:09<00:17,  3.27it/s]#033[A
# #015 36%|███▌      | 31/86 [00:09<00:16,  3.24it/s]#033[A
# #015 37%|███▋      | 32/86 [00:09<00:16,  3.24it/s]#033[A
# #015 38%|███▊      | 33/86 [00:09<00:16,  3.22it/s]#033[A
# #015 40%|███▉      | 34/86 [00:10<00:16,  3.23it/s]#033[A
# #015 41%|████      | 35/86 [00:10<00:15,  3.23it/s]#033[A
# #015 42%|████▏     | 36/86 [00:10<00:15,  3.22it/s]#033[A
# #015 43%|████▎     | 37/86 [00:11<00:15,  3.22it/s]#033[A
# #015 44%|████▍     | 38/86 [00:11<00:15,  3.01it/s]#033[A
# #015 45%|████▌     | 39/86 [00:11<00:14,  3.29it/s]#033[A
# #015 47%|████▋     | 40/86 [00:12<00:14,  3.27it/s]#033[A
# #015 48%|████▊     | 41/86 [00:12<00:13,  3.26it/s]#033[A
# #015 49%|████▉     | 42/86 [00:12<00:13,  3.24it/s]#033[A
# #015 50%|█████     | 43/86 [00:13<00:13,  3.24it/s]#033[A
# #015 51%|█████     | 44/86 [00:13<00:12,  3.24it/s]#033[A
# #015 52%|█████▏    | 45/86 [00:13<00:12,  3.23it/s]#033[A
# #015 53%|█████▎    | 46/86 [00:13<00:12,  3.23it/s]#033[A
# #015 55%|█████▍    | 47/86 [00:14<00:12,  3.23it/s]#033[A
# #015 56%|█████▌    | 48/86 [00:14<00:11,  3.22it/s]#033[A
# #015 57%|█████▋    | 49/86 [00:15<00:12,  2.98it/s]#033[A
# #015 58%|█████▊    | 50/86 [00:15<00:11,  3.24it/s]#033[A
# #015 59%|█████▉    | 51/86 [00:15<00:10,  3.23it/s]#033[A
# #015 60%|██████    | 52/86 [00:15<00:10,  3.23it/s]#033[A
# #015 62%|██████▏   | 53/86 [00:16<00:10,  3.23it/s]#033[A
# #015 63%|██████▎   | 54/86 [00:16<00:09,  3.24it/s]#033[A
# #015 64%|██████▍   | 55/86 [00:16<00:09,  3.23it/s]#033[A
# #015 65%|██████▌   | 56/86 [00:17<00:09,  3.22it/s]#033[A
# #015 66%|██████▋   | 57/86 [00:17<00:09,  3.22it/s]#033[A
# #015 67%|██████▋   | 58/86 [00:17<00:08,  3.21it/s]#033[A
# #015 69%|██████▊   | 59/86 [00:18<00:08,  3.22it/s]#033[A
# #015 70%|██████▉   | 60/86 [00:18<00:08,  2.98it/s]#033[A
# #015 71%|███████   | 61/86 [00:18<00:07,  3.24it/s]#033[A
# #015 72%|███████▏  | 62/86 [00:18<00:07,  3.23it/s]#033[A
# #015 73%|███████▎  | 63/86 [00:19<00:07,  3.23it/s]#033[A
# #015 74%|███████▍  | 64/86 [00:19<00:06,  3.22it/s]#033[A
# #015 76%|███████▌  | 65/86 [00:19<00:06,  3.22it/s]#033[A
# #015 77%|███████▋  | 66/86 [00:20<00:06,  3.22it/s]#033[A
# #015 78%|███████▊  | 67/86 [00:20<00:05,  3.22it/s]#033[A
# #015 79%|███████▉  | 68/86 [00:20<00:05,  3.22it/s]#033[A
# #015 80%|████████  | 69/86 [00:21<00:05,  3.22it/s]#033[A
# #015 81%|████████▏ | 70/86 [00:21<00:04,  3.21it/s]#033[A
# #015 83%|████████▎ | 71/86 [00:21<00:04,  3.21it/s]#033[A
# #015 84%|████████▎ | 72/86 [00:22<00:04,  2.95it/s]#033[A
# #015 85%|████████▍ | 73/86 [00:22<00:04,  3.23it/s]#033[A
# #015 86%|████████▌ | 74/86 [00:22<00:03,  3.22it/s]#033[A
# #015 87%|████████▋ | 75/86 [00:23<00:03,  3.21it/s]#033[A
# #015 88%|████████▊ | 76/86 [00:23<00:03,  3.22it/s]#033[A
# #015 90%|████████▉ | 77/86 [00:23<00:02,  3.22it/s]#033[A
# #015 91%|█████████ | 78/86 [00:24<00:02,  3.19it/s]#033[A
# #015 92%|█████████▏| 79/86 [00:24<00:02,  3.22it/s]#033[A
# #015 93%|█████████▎| 80/86 [00:24<00:01,  3.21it/s]#033[A
# #015 94%|█████████▍| 81/86 [00:24<00:01,  3.21it/s]#033[A
# #015 95%|█████████▌| 82/86 [00:25<00:01,  3.21it/s]#033[A
# #015 97%|█████████▋| 83/86 [00:25<00:00,  3.22it/s]#033[A
# #015 98%|█████████▊| 84/86 [00:25<00:00,  3.21it/s]#033[A
# #015 99%|█████████▉| 85/86 [00:26<00:00,  3.22it/s]#033[A
# #015100%|██████████| 86/86 [00:26<00:00,  2.94it/s]#033[A#015                                                   #015
# #015                                               #015#033[A#015100%|██████████| 1720/1720 [28:04<00:00,  1.23it/s]
# #015100%|██████████| 86/86 [00:26<00:00,  2.94it/s]#033[A
# #015                                               #033[A
# Training completed. Do not forget to share your model on huggingface.co/models =)
# #015                                                   #015#015100%|██████████| 1720/1720 [28:04<00:00,  1.23it/s]#015100%|██████████| 1720/1720 [28:04<00:00,  1.02it/s]
# Saving model checkpoint to /opt/ml/model
# Configuration saved in /opt/ml/model/config.json
# Model weights saved in /opt/ml/model/pytorch_model.bin
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json
# 2023-01-09 12:19:00 Completed - Training job completed
# Training seconds: 1944
# Billable seconds: 1944

# %%
predictor = huggingface_estimator.deploy(initial_instance_count=1, instance_type="ml.c5.xlarge")
# Out:
# ----!

# %%
text = "Tommy is a ridiculous but good dog."

data = {
   "context": text,
    "question":"negative"
}
print(predictor.predict(data))

data = {
   "context": text,
    "question":"positive"
}
print(predictor.predict(data))
data = {
   "context": text,
    "question":"neutral"
}
print(predictor.predict(data))
# Out:
# {'score': 0.30175891518592834, 'start': 11, 'end': 21, 'answer': 'ridiculous'}
# {'score': 0.25432121753692627, 'start': 26, 'end': 30, 'answer': 'good'}
# {'score': 0.9555259943008423, 'start': 0, 'end': 35, 'answer': 'Tommy is a ridiculous but good dog.'}

# %%
text = "Tommy is a ridiculous but good dog."

data = {
   "context": text,
    "question":"negative"
}
print(predictor.predict(data))

data = {
   "context": text,
    "question":"positive"
}
print(predictor.predict(data))
data = {
   "context": text,
    "question":"neutral"
}
print(predictor.predict(data))
# Out:
# {'score': 0.30175891518592834, 'start': 11, 'end': 21, 'answer': 'ridiculous'}
# {'score': 0.25432121753692627, 'start': 26, 'end': 30, 'answer': 'good'}
# {'score': 0.9555259943008423, 'start': 0, 'end': 35, 'answer': 'Tommy is a ridiculous but good dog.'}

# %%
sentences = [
    "Tommy is ridiculous but a good dog.",
    "Day went poor. It was an awesome night.",
    "Pity what a slave this beautiful boy is.",
    "Chelsea lost inspite of their remarkable play.",
    
]
for sentence in sentences:
    for sentiment in ["positive" , "negative"]:
        data = {
           "context": sentence,
            "question":sentiment
        }
        print("Sentence ", sentence)
        print("Sentiment ", sentiment)
        print(predictor.predict(data))
# Out:
# Sentence  Tommy is ridiculous but a good dog.
# Sentiment  positive
# {'score': 0.38624709844589233, 'start': 26, 'end': 30, 'answer': 'good'}
# Sentence  Tommy is ridiculous but a good dog.
# Sentiment  negative
# {'score': 0.3069661855697632, 'start': 9, 'end': 19, 'answer': 'ridiculous'}
# Sentence  Day went poor. Night was fantastic.
# Sentiment  positive
# {'score': 0.6471546292304993, 'start': 25, 'end': 35, 'answer': 'fantastic.'}
# Sentence  Day went poor. Night was fantastic.
# Sentiment  negative
# {'score': 0.3586087226867676, 'start': 0, 'end': 14, 'answer': 'Day went poor.'}
# Sentence  Pity what a slave this beautiful boy is.
# Sentiment  positive
# {'score': 0.45510128140449524, 'start': 0, 'end': 40, 'answer': 'Pity what a slave this beautiful boy is.'}
# Sentence  Pity what a slave this beautiful boy is.
# Sentiment  negative
# {'score': 0.23526301980018616, 'start': 0, 'end': 17, 'answer': 'Pity what a slave'}
# Sentence  Chelsea lost inspite of their remarkable play.
# Sentiment  positive
# {'score': 0.3710714876651764, 'start': 30, 'end': 46, 'answer': 'remarkable play.'}
# Sentence  Chelsea lost inspite of their remarkable play.
# Sentiment  negative
# {'score': 0.3877716362476349, 'start': 8, 'end': 12, 'answer': 'lost'}
